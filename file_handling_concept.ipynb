# %% [markdown]
# # File Handling
#
# - File handling is a process of creating,opening,reading, writing, updating,deleting the files using python..
# - it allows data to be stored permanently on the system..
#
# ## Why do we need file handling :
#
# - Without file handling, data is stored in a variable and lost when the program ends
#
# ### Types of files :
#
# 1. Text file : These files store data in character format. (Exmaple : .txt, .csv, .json, .xml, .html, .py, .ipynb etc)
# 2. Binary File : It stores data in binary format (0 and 1) (Example : .jpg, .png, .mp3, .mp4, .pdf, .exe, etc.)
#
# ### File Operations
#  * Create
#  * Open
#  * Read
#  * Write
#  * Append
#  * Update
#  * Close
#  * Delete

# %% [markdown]
# # File Modes:
#
# - r  : Read only
# - w  : Write(creates file if it doesnt exist, overwrite existing data)
# - a  : Append (adds data at the end)
# - x  : Create a new file(fails if file exists)
# - r+ : Read and Write
# - w+ : Read and write(overwrites existing data)
# - a+ : Read and Append
# - rb : Read binary
# - wb : Write binary
# - ab : Append binary

# %%
name = "Suhani"

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
# Opening a file : 
"""
synatx : 
variable = open("filename","mode")
"""

file = open("new_file.txt","r")

# %%
# Reading a file
file = open("new_file.txt","r")
d = file.read()
d
# Out:
# 'Hi from Suhanii..'

# %%
# read(size) : It reads specified number of character
file = open("new_file.txt","r")
d = file.read(5)
d
# Out:
# 'Hi fr'

# %%
# readline () : Reads one line at a time...

file = open("First_Python_File.py","r")
print(file.readline())
print(file.readline())
file.close()
# Out:
# print("Hello World")
#
# a = 52

# %%
#readlines() : Reads all lines into a list
file = open("First_Python_File.py","r")
print(file.readlines())
file.close()
# Out:
# ['print("Hello World")\n', 'a = 52\n', 'print(a)\n', 'print(type(a))\n', 'a = "Suhani"\n', 'print(type(a))\n', '\n']

# %%
# Writing into a file : 
file = open("new_file.txt","w")
file.write("Hii from Anukul Sir")
file.close()

# %%
# Writing Multiple Lines
file = open("random.txt","w")
file.write("Anukul\n")
file.write("20\n")
file.write("Varanasi\n")
file.close()

# %%
file = open("random.txt","w")
data= ["Sarika Srivastava\n",
       "Sweet 16\n",
       "Varanasi"
       ]
file.writelines(data)
file.close()

# %%
# Append the data

file = open("random.txt","a")
file.write("\nMarried")
file.close()

# %%
# create a file

file = open("EE.txt",'x')
file.close()

# %% [markdown]
# # Reading binary

# %%
file = open(r"C:\Users\dell\Downloads\WhatsApp Image 2026-04-18 at 1.53.57 AM.jpeg","rb") # here r means relative
d = file.read()
print(d)
file.close()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\x06\x06\x06\x06\x07\x06\x07\x08\x08\x07\n\x0b\n\x0b\n\x0f\x0e\x0c\x0c\x0e\x0f\x16\x10\x11\x10\x11\x10\x16"\x15\x19\x15\x15\x19\x15"\x1e$\x1e\x1c\x1e$\x1e6*&&*6>424>LDDL_Z_||\xa7\x01\x06\x06\x06\x06\x07\x06\x07\x08\x08\x07\n\x0b\n\x0b\n\x0f\x0e\x0c\x0c\x0e\x0f\x16\x10\x11\x10\x11\x10\x16"\x15\x19\x15\x15\x19\x15"\x1e$\x1e\x1c\x1e$\x1e6*&&*6>424>LDDL_Z_||\xa7\xff\xc2\x00\x11\x08\x02\xcf\x06@\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x000\x00\x00\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x01\x04\x05\x06\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\xff\xda\x00\x0c\x03\x01\x00\x02\x10\x03\x10\x00\x00\x02\xf5@\xdet\x00\x00\x004\x00\x00\x00\x00\x00\x00\xd0\x00\x00\x00\x007\x03L\xd0\x00\x004\xc0\xd0 \x00\x00\x00(\x00\x03L\xd0\x00\x00\x04\x00\x00\x004\xc3C4\x00\x00\x00\x00\x00\x00\x00\x00\r\x00\x00\x00\x00\x00\x00\x00\x00\x00\x0
# ...
