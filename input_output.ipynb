# %% [markdown]
# # Input

# %%
num = input()
num
# Out:
# 'Anukul'

# %%
num = input("Enter a number")
type(num)
# Out:
# str

# %% [markdown]
# ## type conversion : It means converting one type to another

# %%
num = int(input("Enter a number"))
type(num)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 num = int(input("Enter a number"))
#       2 type(num)
#
# ValueError: invalid literal for int() with base 10: 'Suhani'

# %%
num = float(input("Enter a number"))
type(num)
# Out:
# float

# %%
name = input("Enter object name")
type(name)
# Out:
# str

# %% [markdown]
# # Print function

# %%
print("Suhani Is Studying About Input & output concept")
# Out:
# Suhani Is Studying About Input & output concept

# %%
name = "Suhani"
print(name)
# Out:
# Suhani

# %% [markdown]
# # to add emojis : windown key + dot

# %%
l = [1,2,3,4,5,6]
print(1,2,3,4,5,sep="*",end="😊")
# Out:
# 1*2*3*4*5😊

# %% [markdown]
# ### Formatted string : f string

# %%
name = "Suhani"
print(f'{name} is pursuing Btech in Electrical')
# Out:
# Suhani is pursuing Btech in Electrical

# %%
print(name,"Is pursuing btech",l,"sdc",name,"adsd")
# Out:
# Suhani Is pursuing btech
